# %% [markdown]
# <a href="https://colab.research.google.com/github/putrirahmawati1205/PCVK_Ganjil_2023/blob/main/Week3(1)_PCVK_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print('Mengubah tingkat kecerahan citra')
print('--------------------------------')

try:
  brightness = int(input('Masukkan nilai kecerahan: '))
except ValueError:
  print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/PCVK/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)

#Akses per piksel
for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(original[y,x,c] + brightness, 0, 255)

#Cara simple tanpa loop
#brightness_image = cv.convertScaleAbs(original, beta=brightness)

final_frame = cv.hconcat((original,brightness_image))
cv2_imshow(final_frame)
# Out:
# Mengubah tingkat kecerahan citra
# --------------------------------
# Masukkan nilai kecerahan: 50
# <PIL.Image.Image image mode=RGB size=512x256>

# %% [markdown]
# TASK

# %%
print('Mengubah tingkat kecerahan citra')
print('--------------------------------')

try:
  brightness = int(input('Masukkan nilai kecerahan: '))
except ValueError:
  print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/PCVK/mandrill.tiff')
contras_image = np.zeros(original.shape, original.dtype)

#Akses per piksel
for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(original[y,x,c] + brightness, 0, 255)

#Cara simple tanpa loop
#brightness_image = cv.convertScaleAbs(original, beta=brightness)

final_frame = cv.hconcat((original,brightness_image))
cv2_imshow(final_frame)
# Out:
# Mengubah tingkat kecerahan citra
# --------------------------------
# Masukkan nilai kecerahan: 60
# <PIL.Image.Image image mode=RGB size=1024x512>

# %%
print('Mengubah kontras dan tingkat kecerahan citra')
print('--------------------------------------------')

try:
  brightness = int(input('Masukkan nilai kecerahan [-255-255] : '))
  kontras = float(input('Masukkan kontraas [1.0 - 3.0] : '))
except ValueError:
  print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/PCVK/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)
kontras_image = np.zeros(original.shape, original.dtype)

#Akses per piksel
for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(original[y,x,c] + brightness, 0, 255)
      kontras_image[y,x,c] = np.clip((original*kontras)[y,x,c] + brightness, 0, 255)

#Cara simple tanpa loop
#brightness_image = cv.convertScaleAbs(original, beta=brightness)

final_frame = cv.hconcat((original,kontras_image))
cv2_imshow(final_frame)
# Out:
# Mengubah kontras dan tingkat kecerahan citra
# --------------------------------------------
# Masukkan nilai kecerahan [-255-255] : 60
# Masukkan kontraas [1.0 - 3.0] : 1.5
# <PIL.Image.Image image mode=RGB size=512x256>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

def logarithmic_brightness(image, c):
    transformed_image = c * np.log1p(image)
    transformed_image = np.uint8(transformed_image)

    return transformed_image

original_image = cv2.imread('/content/drive/MyDrive/PCVK/female.tiff')

if original_image is None:
    print("Error: Tidak dapat memuat gambar.")
else:
    print('Mengubah tingkat kecerahan citra dengan transformasi log')
    print('------------------------------------------------------')
    try:
        brightness_factor = float(input('Masukkan nilai kecerahan: '))
    except ValueError:
        print('Error, bukan angka')

    c = 255 / np.log1p(255)

    final_frame = cv.hconcat((original_image,transformed_image))
cv2_imshow(final_frame)
# Out:
# Mengubah tingkat kecerahan citra dengan transformasi log
# ------------------------------------------------------
# Masukkan nilai kecerahan: 40
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-8e32776c54a6> in <cell line: 13>()
#      23     c = 255 / np.log1p(255)
#      24
# ---> 25     final_frame = cv.hconcat((original_image,transformed_image))
#      26 cv2_imshow(final_frame)
#
# NameError: name 'transformed_image' is not defined

# %%
print('Mengubah grayscale avg')
print('--------------------------------')

original = cv.imread('/content/drive/MyDrive/PCVK/mandrill.tiff')
avg_image = np.zeros(original.shape, original.dtype)


#we need to transform this in order that Matplotlib reads it correctly
fix_img = cv.cvtColor(original, cv.COLOR_BGR2RGB)
plt.imshow(fix_img)

avg_image = np.mean(fix_img, axis=2)
plt.imshow(avg_image, cmap='gray')
# Out:
# Mengubah grayscale avg
# --------------------------------
